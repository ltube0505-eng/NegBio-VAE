# %%
import numpy as np
import os
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from itertools import combinations
from tqdm import tqdm

# %%
model_name = "categorial"

# %%
# !ls .save
# Out:
# analysis latents  MNIST    Omniglot

# %%
path = ".save/Omniglot/{}/gamma/gumbel/latents/".format(model_name)

# %%
z = np.load(os.path.join(path,"test_z_all.npy"))
y = np.load(os.path.join(path,"test_y_all.npy"))

# %%
z.shape
# Out:
# (13180, 10)

# %%
z.shape
# Out:
# (25, 10)

# %%
X_train, x_test = z[:5000], z[5000:]
y_train, y_test = y[:5000], y[5000:]

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train, y_train)
y_pred = knn.predict(x_test)
acc = accuracy_score(y_test, y_pred)

# %%
acc
# Out:
# 0.0

# %%
y_train
# Out:
# array([5, 1, 7, 2, 5, 5, 3, 7, 9, 6, 3, 0, 1, 9, 2, 4, 1, 5, 8, 3, 6, 7])

# %%
y_test
# Out:
# array([9, 7, 5])

# %%
y_pred
# Out:
# array([1, 7, 1])
